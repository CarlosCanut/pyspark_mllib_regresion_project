# %%
import pandas as pd
from IPython.display import display, HTML

# %% [markdown]
# Primero extraemos los datos de todos los partidos desde el 2010 hasta el 2021 y los rankings de cada decada:

# %%
# partidos
games = []
for year in [2010, 2011, 2012, 2013, 2014, 2015, 2016, 2017, 2018, 2019, 2020, 2021]:
    games.append(pd.read_csv("datasets/atp_matches_"+ str(year) +".csv"))
all_atp_games = pd.concat(games)

# rankings
ranking_atp_10s = pd.read_csv("datasets/atp_rankings_10s.csv")
ranking_atp_20s = pd.read_csv("datasets/atp_rankings_20s.csv")
all_ranking = []
all_ranking.append(ranking_atp_10s)
all_ranking.append(ranking_atp_20s)
all_ranking_atp = pd.concat(all_ranking)

# %%
all_atp_games.columns
# Out:
# Index(['tourney_id', 'tourney_name', 'surface', 'draw_size', 'tourney_level',
#        'tourney_date', 'match_num', 'winner_id', 'winner_seed', 'winner_entry',
#        'winner_name', 'winner_hand', 'winner_ht', 'winner_ioc', 'winner_age',
#        'loser_id', 'loser_seed', 'loser_entry', 'loser_name', 'loser_hand',
#        'loser_ht', 'loser_ioc', 'loser_age', 'score', 'best_of', 'round',
#        'minutes', 'w_ace', 'w_df', 'w_svpt', 'w_1stIn', 'w_1stWon', 'w_2ndWon',
#        'w_SvGms', 'w_bpSaved', 'w_bpFaced', 'l_ace', 'l_df', 'l_svpt',
#        'l_1stIn', 'l_1stWon', 'l_2ndWon', 'l_SvGms', 'l_bpSaved', 'l_bpFaced',
#        'winner_rank', 'winner_rank_points', 'loser_rank', 'loser_rank_points'],
#       dtype='object')

# %%
all_atp_games.to_csv("datasets/all_atp_games.csv", index=False)

# %%
all_ranking_atp
# Out:
#        ranking_date  rank    player   points    20200106      1    104745  \
# 0        20100104.0   1.0  103819.0  10550.0         NaN    NaN       NaN
# 1        20100104.0   2.0  104745.0   9205.0         NaN    NaN       NaN
# 2        20100104.0   3.0  104925.0   8310.0         NaN    NaN       NaN
# 3        20100104.0   4.0  104918.0   7030.0         NaN    NaN       NaN
# 4        20100104.0   5.0  105223.0   6785.0         NaN    NaN       NaN
# ...             ...   ...       ...      ...         ...    ...       ...
# 53151           NaN   NaN       NaN      NaN  20201228.0  896.0  126762.0
# 53152           NaN   NaN       NaN      NaN  20201228.0  897.0  209857.0
# 53153           NaN   NaN       NaN      NaN  20201228.0  898.0  103565.0
# 53154           NaN   NaN       NaN      NaN  20201228.0  899.0  125800.0
# 53155           NaN   NaN       NaN      NaN  20201228.0  900.0  132575.0
#
#        9985
# 0       NaN
# 1       NaN
# 2       NaN
# 3       NaN
# ...

# %%
css = """
.output {
    flex-direction: row;
}
"""
HTML('<style>{}</style>'.format(css))
# Out:
# <style>
# .output {
#     flex-direction: row;
# }
# </style>

# %%
display(ranking_atp_10s)
display(ranking_atp_20s)
# Out:
#         ranking_date  rank  player   points
# 0           20100104     1  103819  10550.0
# 1           20100104     2  104745   9205.0
# 2           20100104     3  104925   8310.0
# 3           20100104     4  104918   7030.0
# 4           20100104     5  105223   6785.0
# ...              ...   ...     ...      ...
# 915613      20191230  1922  134833      1.0
# 915614      20191230  1922  144856      1.0
# 915615      20191230  1922  202326      1.0
# 915616      20191230  1926  207307      1.0
# 915617      20191230  1927  208186      1.0
#
# [915618 rows x 4 columns]
#        20200106    1  104745  9985
# 0      20200106    2  104925  9055
# 1      20200106    3  103819  6590
# 2      20200106    4  106233  5825
# 3      20200106    5  106421  5705
# 4      20200106    6  126774  5300
# ...         ...  ...     ...   ...
# 53151  20201228  896  126762    15
# 53152  20201228  897  209857    15
# 53153  20201228  898  103565    15
# 53154  20201228  899  125800    15
# ...

# %%
all_atp_games['date'] = all_atp_games.apply(lambda row: str(row.tourney_date)[:4], axis=1)
pd.unique(all_atp_games.date)
# Out:
# array(['2010', '2011', '2012', '2013', '2014', '2015', '2016', '2017',
#        '2018', '2019', '2020', '2021'], dtype=object)
